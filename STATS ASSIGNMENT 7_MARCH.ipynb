# %%
Q1:The three measures of central tendency are mean,median,mode.

Q2:MEAN: It calculates the average of datasets.
example: if datasets are 1,2,3,4,5
then mean=xbar=(1+2+3+4+5)/5
               =15/5
               =3
Median:It calculates the middle value of any observations.
ex:if datasets are 1,2,3,4,5
median =middle most observations when data are arranged in ascending order.
in this case median is 3
MODE:It represent the data which have most frequency.
example: if datasets are 1,5,6,7,8,9,0,2,2,5
IN this case datasets 2 have frequency 2 which is maximum in this datasets so mode is 2.

Q3:MEAN=177.08175
MEDIAN=177.0
MODE=177.0

Q4: STANDARD DEVIATION=1.788

Q5:Measures of dispersion are 
(i) variance
(ii) standard deviation
(iii) range
variance:it represents the spread of datasets about its mean.
sample vrainace(S**2)=(sigma(xi-xbar)**2))/n-1
here xi=datasets which represent ith value
xbar=mean of the dataset
n=sample size of dataset

population variance(sigma**2)=(sigma(xi=xbar)**2))/N
here,xi=ith observation of dataset
xbar=mean of dataset
N=population size of dataset
standard devation: it is positive square root of variance.
population_standard_deviation(sigma)=(populatio_variance)**0.5
sample_standard_deviation(S)=(sample_variance)**0.5
range:It is differnce of maximum observation of dataset and minimum observation of dataset.
ex:if dataset are 1,2,3,4,5
range=5-1=4

Q6:Venn diagrams are the pictorial representaion of sets.

Q7:(i)A UNION B=(2,6)
   (ii) A INTERSECTION B=(0,2,3,4,5,6,7,8,10)
    
Q8:Skewness is a mesurement of the distortion of symmetrical distribution or asymmetry
in a dataset.

Q9:Median is left side of the mean if data is right skewed.

Q10:COVARINCE:It quantifies the realtionship between two random variables .it can be positive ,negative.
The value of covariance have not any specific range.
CORRELATION:It quantifies the realtionship between random variables.it values lies
between -1 to 1.it represents how random variables and how much correlated.

Q11:SAMPLE MEAN=(x1+x2+x3+........+xn)/n
xi=ith observation of datsets 
n=sample size of datsets
ex:if datasets are 1,2,3,4,5
sample_mean(xbar)=(1+2+3+4+5)/5
                =3

Q12:for a normal distribution ,all measures of central tendency are same.
ie:,mean=median=mode.

Q13:Covariance different from correlation in many ways:
(i)covariance shows how two variables are differ whereas correlation shows how the two
variables are related.
(ii)covariance have not any specific range while correlation have range of -1 to 1.

Q14:outliers effect the mean value of the data but little effect on median or mode of
a given set of data.
outliers effect measures of dispersion:
outliers effect variance and standard deviation but most effect range of a dataset.
